# %% [markdown]
# ## 경로 수정 및 라이브러리 import
# 현재 프로젝트의 경로를 /root/notebooks 에서 /root로 변경합니다.
# import_libraries.py에서 라이브러리를 자동으로 import 합니다.
#
# `%cd` 뒤에 프로젝트 루트의 경로를 입력해주면 됩니다.

# %%
# %cd /Users/parksanghwan/work/sample_1
# %pwd
# %run configs/import_libraries.py
# Out:
# /Users/parksanghwan/work/sample_1

# %% [markdown]
# ### 라이브러리 설치 코드
# 혹시나 모듈이 설치가 안되었을 경우 아래 코드를 이용하여 설치하면 됩니다.

# %%
# %pip install --upgrade "torch==2.13.0" "torchvision==0.28.0" albumentations
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 외부모듈 오토 리로드

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 코드 실행

# %%
import configs.config as cfg

cfg = cfg.cfg

# %% [markdown]
# ## 데이터 확인
# 데이터의 수량이나 RGB 표준편차 등 전처리 전 확인 작업을 진행하는 공간입니다.

# %% [markdown]
# ## 데이터 증강과 전처리

# %%
from datasets import data_augment as aug

train_transform = aug.get_train_transform()

# %% [markdown]
# ## 데이터셋 로더 빌드

# %% [markdown]
# ## 모델 정의

# %% [markdown]
# ## 손실함수와 최적화 함수 정의

# %% [markdown]
# ## 모델 학습

# %% [markdown]
# ## 평가, 테스트

# %% [markdown]
# ## 최적의 모델 저장
